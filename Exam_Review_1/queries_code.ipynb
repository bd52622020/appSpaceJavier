# %%
#--------------------------------------------------- 
#Tools: Excel, Python Pandas
    # Print a list of the 10 movies that received the most number of ratings, sorted by the number of ratings.
    #------------- Print a list of the number of ratings received by each genre.
    #--------------------------------- Print the oldest movie with a “5” rating.
    #---------------- Print a list of the genre of the top 10 most rated movies.
    #---------- Print the title of the movie that was rated the most by students
    #--- Print the list of movies that received the highest number of “5” rating
    # Print the list of zip codes corresponding to the highest number of users that rated movies.
    #------------- Find the most rated movie by users in the age group 20 to 25.
    #------------------ Print the list of movies that were rate after year 1960.
#------------------------------------------------------------------------- BONUS
# 1) Convert UnixTimeStamp in  timestamp column of u.data to human readable date

import pandas as pd;
import numpy as np;
from datetime import datetime;

path = "./"
species = pd.read_csv(path + 'species.csv', sep=',', encoding = "ISO-8859-1")

characters = pd.read_csv(path + 'characters.csv', sep=',', encoding = "ISO-8859-1")
starships = pd.read_csv(path + 'starships.csv', sep=',', encoding = "ISO-8859-1")

# %%
species.head()
# Out:
#              name classification designation  average_height  \
# 0            Hutt      gastropod    sentient           300.0
# 1  Yoda's species         mammal    sentient            66.0
# 2      Trandoshan        reptile    sentient           200.0
# 3    Mon Calamari      amphibian    sentient           160.0
# 4            Ewok         mammal    sentient           100.0
#
#                  skin_colors          hair_colors            eye_colors  \
# 0          green, brown, tan                  NaN           yellow, red
# 1              green, yellow         brown, white  brown, green, yellow
# 2               brown, green                 none        yellow, orange
# 3  red, blue, brown, magenta                 none                yellow
# 4                      brown  white, brown, black         orange, brown
#
#   average_lifespan        language  homeworld
# 0             1000         Huttese  Nal Hutta
# 1              900  Galactic basic        NaN
# ...

# %%
characters.head()
# Out:
#              name  height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %%
starships.head()
# Out:
#                            name                            model  \
# 0                      Executor  Executor-class star dreadnought
# 1  Sentinel-class landing craft     Sentinel-class landing craft
# 2                    Death Star      DS-1 Orbital Battle Station
# 3             Millennium Falcon          YT-1300 light freighter
# 4                        Y-wing                       BTL Y-wing
#
#                                         manufacturer  cost_in_credits  length  \
# 0                 Kuat Drive Yards, Fondor Shipyards     1.143350e+09   19000
# 1            Sienar Fleet Systems, Cyngus Spaceworks     2.400000e+05      38
# 2  Imperial Department of Military Research, Sien...     1.000000e+12  120000
# 3                  Corellian Engineering Corporation     1.000000e+05   34.37
# 4                             Koensayr Manufacturing     1.349990e+05      14
#
#   max_atmosphering_speed      crew  passengers  cargo_capacity consumables  \
# ...

# %%
# 1. Which is the species most common in the characters of Star Wars
characters["species"].value_counts(sort=True).head(3)
# Out:
# Human     35
# Droid      5
# Gungan     3
# Name: species, dtype: int64

# %%
# 2. Which predominant language in the characters
characters_species = pd.merge(characters, species, left_on='species', right_on='name')
characters_species["language"].value_counts(sort=True).head(5)
# Out:
# Galactic Basic    36
# Gungan basic       3
# Twi'leki           2
# Zabraki            2
# Mirialan           2
# Name: language, dtype: int64

# %%
# 3. Who is the tallest person in the characters
characters[characters["height"] == characters["height"].max()].head(1)
# Out:
#            name  height mass hair_color skin_color eye_color birth_year  \
# 53  Yarael Poof   264.0  NaN       none      white    yellow        NaN
#
#    gender homeworld   species
# 53   male   Quermia  Quermian

# %%
# 4. How much costs all the starships together
starships["cost_in_credits"].sum()
# Out:
# 1001710771198.0

# %%
# 5. Which cargo can carry more passengers with length less than 5000
starships[starships["length"] < 5000].show(10)

# I need to pass the column to Integer but I do not have more time +)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-649c6856358c> in <module>
#       1 # 5. Which cargo can carry more passengers with length less than 5000
# ----> 2 starships[starships["length"] < 5000].show(10)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ...
